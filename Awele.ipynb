# %%
try:
    import numpy as np
except ImportError:
    print("Sorry, this example requires Numpy installed!")
    raise

from easyAI import TwoPlayerGame


class Awele(TwoPlayerGame):
    def __init__(self, players):
        for i, player in enumerate(players):
            player.score = 0
            player.isstarved = False
            player.camp = i
        self.players = players
        
        # initial configuration of the board.
        # holes are indexed by a,b,c,d..
        self.board = [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]
        
        self.current_player = 1

    def make_move(self, move):
        if move == "None":
            self.player.isstarved = True
            s = 6 * self.opponent.camp
            self.player.score += sum(self.board[s: s + 6])
            return
        
        move = "abcdefghijkl".index(move)
        
        pos = move
        for i in range(self.board[move]):
            pos = (pos + 1) % 12
            if pos == move:
                pos = (pos + 1) % 12
            self.board[pos] += 1
            
            while (pos // 6) == self.opponent.camp and (self.board[pos] in [2, 3]):
                self.player.score += self.board[pos]
                self.board[pos] = 0
                pos = (pos - 1) % 12

    def possible_moves(self):
        '''
        A player must any hole that contains enough seeds to
        "feed" the opponent. this no hole has this many seeds,
        any non-empty hole can be played
        '''
        if self.current_player == 1:
            if max(self.board[:6]) == 0:
                return ["None"]
            moves = [i for i in range(6) if (self.board[i] >= 6 - i)]
            if moves == []:
                moves = [i for i in range(6) if self.board[i] != 0]

            return ["abcdefghijkl"[u] for u in moves]
    
    def show(self):
        print("Score: %d / %d" % tuple(p.score for p in self.players))
        print(" ".join("lkjihg"))
        print(" ".join(["%02d" % i for i in self.board[-1:-7:-1]]))
        print(" ".join(["%02d" % i for i in self.board[:6]]))
        print(" ".join("abcdef"))

    def lose(self):
        return self.opponent.score > 24
    
    def is_over(self):
        return self.lose() or sum(self.board) < 7 or self.opponent.isstarved

if __name__ == "__main__":
    from easyAI import Human_Player, AI_Player, Negamax
    # this shows that the scoring can be defined in the AI algo
    # whi enables 2 AIs with different scoring to play a math
    scoring = lambda game: game.player.score - game.opponent.score
    ai = Negamax(6, scoring)
    game = Awele([AI_Player(ai), AI_Player(ai)])

    game.play()

    if game.player.score > game.opponent.score:
        print("Player %d wins." % game.current_player)
    elif game.player.score < game.opponent.score:
        print("Player %d wins. "% game.opponent_index)
    else:
        print("Looks like we have a draw.")
# Out:
# Score: 0 / 0
# l k j i h g
# 04 04 04 04 04 04
# 04 04 04 04 04 04
# a b c d e f
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 81
#      78 ai = Negamax(6, scoring)
#      79 game = Awele([AI_Player(ai), AI_Player(ai)])
# ---> 81 game.play()
#      83 if game.player.score > game.opponent.score:
#      84     print("Player %d wins." % game.current_player)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyAI\TwoPlayerGame.py:110, in TwoPlayerGame.play(self, nmoves, verbose)
#     107 if self.is_over():
#     108     break
# --> 110 move = self.player.ask_move(self)
#     111 history.append((deepcopy(self), move))
#     112 self.make_move(move)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyAI\Player.py:63, in AI_Player.ask_move(self, game)
#      62 def ask_move(self, game):
# ---> 63     return self.AI_algo(game)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyAI\AI\Negamax.py:178, in Negamax.__call__(self, game)
#     170 """
#     171 Returns the AI's best move given the current state of the game.
#     172 """
#     174 scoring = (
#     175     self.scoring if self.scoring else (lambda g: g.scoring())
#     176 )  # horrible hack
# --> 178 self.alpha = negamax(
#     179     game,
#     180     self.depth,
#     181     self.depth,
#     182     scoring,
#     183     -self.win_score,
#     184     +self.win_score,
#     185     self.tt,
#     186 )
#     187 return game.ai_move
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyAI\AI\Negamax.py:79, in negamax(game, depth, origDepth, scoring, alpha, beta, tt)
#      76 game.make_move(move)
#      77 game.switch_player()
# ---> 79 move_alpha = -negamax(game, depth - 1, origDepth, scoring, -beta, -alpha, tt)
#      81 if unmake_move:
#      82     game.switch_player()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\easyAI\AI\Negamax.py:64, in negamax(game, depth, origDepth, scoring, alpha, beta, tt)
#      61     possible_moves = game.possible_moves()
#      63 state = game
# ---> 64 best_move = possible_moves[0]
#      65 if depth == origDepth:
#      66     state.ai_move = possible_moves[0]
#
# TypeError: 'NoneType' object is not subscriptable
